# %% [markdown]
# #***Python Introduction:***
#
#
# Python is a high-level programming language known for its simple and readable syntax.
#
# - It has the following features:
#
#   - Allows writing clean code with fewer lines.
#   - Supports multiple programming paradigms including object-oriented, functional and procedural programming.
#   - Widely used in web development, automation, data analysis, artificial intelligence and many other fields.
#   - Dynamically typed and has automatic garbage collection

# %%
# Hello World Program
# The Hello World program demonstrates the basic structure of a Python program.

print("Hello!! , Welcome to Python Programming!")
# Out:
# Hello!! , Welcome to Python Programming!

# %% [markdown]
# #How does this work:
#
# - print() is a built-in Python function that instructs the computer to display text on the screen.
# - "Hello, World!" is a string enclosed within quotes (either single ' or double ").
# - Python uses indentation (spaces or tabs) to define code blocks instead of braces {} in C, C++ and Java .
# -  #is used to write comments in Python. Comments are ignored during execution.

# %% [markdown]
# #***Python Data Types:***
#
# - Data types in Python define the type of value stored in a variable and determine the operations that can be performed on that data. Since Python treats everything as an object, each value is associated with a specific data type.
#
#   - Helps the interpreter understand how to store and process different kinds of data efficiently.
#   - Enables correct operations by ensuring only valid actions are performed on compatible data types.
#
#   ![Screenshot 2026-06-24 073541.png](data:image/png;base64,...)
#
# #***1.Numeric Data Types***
#  - Numeric data types are used to store numeric values. It can be an integer, floating number or even a complex number.
#    - Python supports three main numeric types:
#      - Integers: value is represented by int class. It contains positive or negative whole numbers (without fractions or decimals).
#      - Float: value is represented by float class. It is a real number with a floating-point representation. It is specified by a decimal point.
#      - Complex: It is represented by a complex class. It stores numbers with real and imaginary parts. For example: 2+3j
#
#
# #***2.Sequence Data Types:***
# -  A sequence is an ordered collection of items, which can be of similar or different data types. Elements in a sequence can be accessed using indexing.
#
#    - ***A) String :***
#           - Strings are used to store text data. A string is represented using the str class and can be created using single, double or triple quotes.
#    - ***B) List :***
#           - Lists are ordered and mutable collections used to store multiple items in a single variable. Elements in a list can be of different data types and are accessed using indexing.
#    - ***C) Tuple :***
#            - Tuples are ordered and immutable collections used to store multiple items in a single variable. Once created, tuple elements cannot be modified and are accessed using indexing.
#
#            - ***Note:*** A tuple with a single element must include a trailing comma, otherwise Python treats it as a normal value instead of a tuple.
#
#
# #***3.Boolean Data Type :***
# -  Boolean data type represents one of two values: True or False.
# - It is mainly used in conditions and comparisons and is represented by the bool class.
#
#  ***Truthy and Falsy Values:***
#   - truthy and falsy values are values that evaluate to True or False in a Boolean context. Truthy values behave like True, while falsy values behave like False when used in conditions.
#
#
# #***4.Set Data Type :***
# - Sets are unordered and mutable collections used to store unique elements. Since sets are unordered, elements cannot be accessed using indexing.
# - Elements are usually accessed by iterating through the set using a loop.
#   - ***Note:*** Sets in Python are unordered, so the order of elements when printed may vary each time the code is run.
#
# #***5.Dictionary Data Type:***
# - Dictionaries are used to store data in key:value pairs. Each key in a dictionary must be unique and values are accessed using their keys with square brackets [ ] or get( ) method.
#
#  - ***Note:*** Dictionary keys are case sensitive, the same name but different cases of Key will be treated distinctly.

# %%
# Numeric Data Types :

a = 5
b = 5.0
c = 2+3j

print(type(a))  #type() give the class of the particular data that it holds.

print(type(b))

print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
# String data type :
s = "Welcome to the Geeks World"
print(s)
print(type(s))  #type() give the class of the particular data that it holds.

# access string with index
print(s[1])  # s[1] gives the value of the 1st index of the string , from left to right , index starts from 0.
print(s[-1]) # s[-1] gives the value of the 1st index of the string , from right to left,  index starts from -1.
# Out:
# Welcome to the Geeks World
# <class 'str'>
# e
# d

# %%
# List data type : lists are enclosed in square brackets [ ]

a = [1, 2, 3]
print(a)

b = ["Geeks", "For", "Geeks", 4, 5]
print(b[3])
print(b[-3])
# Out:
# [1, 2, 3]
# 4
# Geeks

# %%
# Tuple data type : Tuples are enclosed in ( )

t1 = (1,2)
print(type(t1))

t2 = ('Geeks', 'For', 'Geeks', 1, 2)
print(t2[3])
print(t2[-3])
# Out:
# <class 'tuple'>
# 1
# Geeks

# %%
# Boolean data type :

print(type(True))
print(type(False))

if 1:
    print("1 is truthy")

if not 0:
    print("0 is falsy")
# Out:
# <class 'bool'>
# <class 'bool'>
# 1 is truthy
# 0 is falsy

# %%
# Set Data type :

s1 = {"a", "a", "b", "c", "b"}
print(s1)

s2 = {"Geeks", "For", "Geeks"}
for i in s2:
    print(i)
# Out:
# {'b', 'c', 'a'}
# For
# Geeks

# %%
# Dictionary Data type : Dictionary holds the data in key:value pairs , they are case sensitive and they are created using [ ] or ( )

dict = {"Name":" Kiran" , "Age":30 , "City": "Channapatna"}

print(dict)

print(dict["Name"])

print(dict.get("Age"))

print(dict.get("City"))
# Out:
# {'Name': ' Kiran', 'Age': 30, 'City': 'Channapatna'}
#  Kiran
# 30
# Channapatna

# %% [markdown]
# #***Python Operators :***
#
# - In Python programming, Operators in general are used to perform operations on values and variables.
#
#   - Operators: Special symbols like -, + , * , /, etc.
#   - Operands: Value on which the operator is applied.
#
# #***Types of Operators in Python:***
# ![image.png](data:image/png;base64,...)
#
#
# #***1.Arithmetic Operators :****
#
# - Arithmetic operators are used to perform basic mathematical operations like addition, subtraction, multiplication and division.
#
# - In Python, the division operator (/) returns a floating-point result, while floor division (//) returns an integer result.
#
# #***2.Comparison Operators :***
#
# - Comparison(or Relational) operators compares values. It either returns True or False according to the condition.
#
# #***3.Logical Operators :***
#
# - Logical operators perform Logical AND, Logical OR and Logical NOT operations. It is used to combine conditional statements.
#
# - The precedence of Logical Operators in Python is as follows:
#
#   - Logical NOT
#   - logical AND
#   - logical OR
#
# #***4.Bitwise Operators :***
#
# -Bitwise operators act on bits and perform bit-by-bit operations. These are used to operate on binary numbers.
#
# - Bitwise Operators in Python are as follows:
#
#   - Bitwise NOT
#   - Bitwise Shift
#   - Bitwise AND
#   - Bitwise XOR
#   - Bitwise OR
#
# #***5.Assignment Operators :***
#
# - Assignment operators are used to assign values to the variables. This operator is used to assign the value of the right side of the expression to the left side operand.
#
# - Walrus Operator
# The Walrus Operator is a new assignment expression operator introduced in Python 3.8 and higher. This operator is used to assign a value to a variable within an expression.
#
#   - Example: In this code, we have a Python list of integers. We have used Python Walrus assignment operator within the Python while loop. The operator evaluates the expression on the right-hand side and assigns the result to the variable on the left-hand side operand 'x' and then execute the remaining code.
#       # a list
#       a = [1, 2, 3, 4, 5]
#
#       # walrus operator
#       while(x := len(a)) > 2:
#       a.pop()
#       print(x)
#
#       Output
#        5
#        4
#        3
#  - ***Syntax: a := expression***
#
# #***6.Identity Operators :***
#
# - "is" and "is not" are the identity operators and both are used to check if two values are located on the same part of the memory. Two variables that are equal do not imply that they are identical.
#
#   - is     :>> True if the operands are identical
#   - is not :>> True if the operands are not identical
#
# #***7.Membership Operators :***
#
# - "in" and "not in" are the membership operators that are used to test whether a value or variable is in a sequence.
#
#   - in      :>> True if value is found in the sequence
#   - not in  :>> True if value is not found in the sequence
#
# #***8.Ternary Operator :***
#
# - Ternary operators also known as conditional expressions are operators that evaluate something based on a condition being true or false.
# - It was added to Python in version 2.5.
#
#   - It simply allows testing a condition in a single line replacing the multiline if-else, making the code compact.
#
#      - Syntax :  ***[on_true] if [expression] else [on_false]***
#
# #***9.Precedence and Associativity of Operators :***
# - Operator precedence and associativity determine the priorities of the operator.
#
# - Operator Precedence :
#   - This is used in an expression with more than one operator with different precedence to determine which operation to perform first.
#
# - Operator Associativity :
#    - If an expression contains two or more operators with the same precedence then Operator Associativity is used to determine. It can either be Left to Right or from Right to Left.

# %%
# ARITHMETIC OPERATIONS :

a = 20
b = 5

print("Addition : " , a+b)
print("Subtraction : " , a-b)
print("Multiplication : " , a*b)
print("Division : " , a/b) # gives float value
print("Floor Division : " , a//b) # gives the integer value nearest
print("Modulus : " , a%b)
print("Exponentiation : " , a**b)
# Out:
# Addition :  25
# Subtraction :  15
# Multiplication :  100
# Division :  4.0
# Floor Division :  4
# Modulus :  0
# Exponentiation :  3200000

# %%
# COMPARISION OPERATORS :

a = 20
b = 5

print(a > b) # is greater than
print(a < b) # is lesser than
print(a == b) # is equal to
print(a != b) # is not equal to
print(a >= b) # is greater than or equal to
print(a <= b) # is lesser than or equal to
# Out:
# True
# False
# False
# True
# True
# False

# %%
# LOGICAL OPERATORS :

a = True
b = False

print(a and b)
print(a or b)
print(not a)
print(not b)

print(b and a)
print(b or a)
# Out:
# False
# True
# False
# True
# False
# True

# %%
# BITWISE OPERATORS :

a = 10
b = 4

print(a & b) # Bitwise AND (&) : Compares each bit and returns 1 only if both bits are 1.

print(a | b) #Bitwise OR (|) : Returns 1 if at least one bit is 1.

print(~a)  #Bitwise NOT( ~ ) : Flips all bits (0 → 1, 1 → 0).

print(a ^ b) #Bitwise XOR (^) : Returns 1 only when the bits are different.

print(a >> 2) #Right Shift (>>) : Shifts all bits 2 positions to the right.

print(a << 2) #Left Shift (<<) : Shifts all bits 2 positions to the left.
# Out:
# 0
# 14
# -11
# 14
# 2
# 40

# %%
# ASSIGNMENT OPERATORS :

a = 10
b = a

print(b) # here b stores the value of a , so output will be 10

b += a   # here b value will be equal to original value of a plus b pointing value of a , so it will be adding both the values , so output will be 20
print(b)

b -= a   # here b value will be equal to value of above expression i.e 20 minus b pointing value of a , so it will be subtracting from the values of b from above and a value , so output will be 10
print(b)

b *= a # here b value will be 10 from above expression and the multiplies with original value of a i.e 10 , so output will be 100
print(b)

b <<= a # here a stores value of 10 , then for value of b , it uses left shift operator and It shifts all bits to the left by the specified number of positions . here 10 positions , and then completely shifts by 10 positions and then assigns value of a , so output will be 102400
print(b)
# Out:
# 10
# 20
# 10
# 100
# 102400

# %%
# IDENTITY OPERATORS :

a = 10
b = 20
c = a

print(a is not b) # it says a isnt b , so 10 is not 20 , so true comes out as output
print(a is c) # here c is storing value of a , so it says c is a , so output is true.
# Out:
# True
# True

# %%
# MEMBERSHIP OPERATORS : test whether a value or variable is in a sequence.

x = 24
y = 20
my_list = [10, 20, 30, 40, 50]

if (x not in my_list):
    print("x is NOT present in given list")
else:
    print("x is present in given list")

if (y in my_list):
    print("y is present in given list")
else:
    print("y is NOT present in given list")
# Out:
# x is NOT present in given list
# y is present in given list

# %%
# TERNARY OPERATOR :

a, b = 10, 20
min = a if (a < b) else b

print(min)

a,b = 20 , 100
max = a if (a>b) else b
print(max)
# Out:
# 10
# 100

# %%
# Precedence and Associativity of Operators :

# 1) Operator Precedence :This is used in an expression with more than one operator with different precedence to determine which operation to perform first.


expr = 10 + 20 * 30
print(expr)
name = "Alex"
age = 0

if name == "Alex" or name == "John" and age >= 2:
    print("Hello! Welcome.")
else:
    print("Good Bye!!")

# 2) Operator Associativity : If an expression contains two or more operators with the same precedence then Operator Associativity is used to determine. It can either be Left to Right or from Right to Left.

print(100 / 10 * 10) # Uses BODMAS rule : first division and then multiplication
print(5 - 2 + 3) # first (3-2 = 1) then adds 5
print(5 - (2 + 3)) # first terms in bracket gets executed and then executes next expression (2+3=5) , then 5-5 , so output is 0
print(2 ** 3 ** 2) # first 3**2 gets executed , then (3**2 = 9), so 2 power 9 gets executed.
# Out:
# 610
# Hello! Welcome.
# 100.0
# 6
# 0
# 512

# %% [markdown]
# #***Type Casting in Python :***
#
# - Type Casting is the method to convert the Python variable datatype into a certain data type in order to perform the required operation by users. We will see various techniques for typecasting.
# - There can be two types of Type Casting in Python:
#   - Implicit Type Conversion
#   - Explicit Type Conversion
#
# #***1) Implicit Type Conversion :***
# - Implicit type conversion occurs when Python automatically converts one data type to another during an operation to ensure correct and safe evaluation, without requiring any action from the user.
#
# #***2) Explicit Type Conversion :***
# - Explicit type conversion is when the programmer manually changes a value’s data type using built-in type casting functions, usually when automatic conversion is not possible or a specific type is needed.
#
# - *Examples of Type Casting:*
#   - Commonly used type casting functions in Python are:
#     - ***Int( )*** function take float or string as an argument and returns int type object.
#     - ***float( )*** function take int or string as an argument and return float type object.
#     - ***str( )*** function takes float or int as an argument and returns string type object.
#
#   - ***Convert Int to Float*** : Converting Int to Float in with the float( ) function.
#   - ***Convert Float to Int*** : Converting Float to int datatype in Python with int( ) function.
#   - ***Convert int to String :*** Converting int to String datatype in Python with str( ) function.
#   - ***Convert String to float :*** casting string data type into float data type with float( ) function.
#   - ***Convert string to int :*** Converting string to int datatype in Python with int() function. If the given string is not number, then it will throw an error.
#   - ***Adding String and Integer Without Conversion :*** If we try to directly add an integer and a string, Python will throw an error because they are different data types.

# %%
# 1). Implicit Type Conversion :

# Python automatically converts 'a' to int
a = 7
print(type(a)) # a is integer here , so it gives class as integer

# Python automatically converts 'b' to float
b = 3.0
print(type(b)) # b is decimal here , so for decimals it gives class as float

# Python automatically converts 'c' to float as it is a float addition
c = a + b
print(c)
print(type(c)) # here a is integer ,b is float here, so output will be also float

# Python automatically converts 'd' to float as it is a float multiplication
d = a * b
print(d)
print(type(d)) # here a is integer ,b is float here, so output will be also float


# 2). Explicit Type Conversion :

# 2.1) Convert Int to Float :Converting Int to Float in with the float() function.


a = 5 # here a is integer
n = float(a) # here using float( ) converts integer into float.

print(n)
print(type(n))

# 2.2) Convert Float to Int : Converting Float to int datatype in Python with int() function.


a = 5.9 # here a is integer
n = int(a) # here using int( ) converts float into integer.

print(n)
print(type(n))

# 2.3) Convert int to String  : Converting int to String datatype in Python with str() function.

a = 5
# typecast to str
n = str(a)

print(n)
print(type(n))

# 2.4) Convert String to float : Casting string data type into float data type with float() function.

a = "5.9" # a is string here
n = float(a)

print(n)
print(type(n))

# 2.5) Convert string to int : Converting string to int datatype in Python with int() function. If the given string is not number, then it will throw an error.

a = "5"  # a is string
b = 't'  # b is string
n = int(a) # converting string to integer

print(n) # it will be integer
print(type(n)) # class integer

#The string "5" is successfully converted into an integer 5. Since 't' is not a number, Python cannot convert it into an integer.


print(int(b)) # b is a string here , so it cannot be converted to integer here
print(type(b))
# Out:
# <class 'int'>
# <class 'float'>
# 10.0
# <class 'float'>
# 21.0
# <class 'float'>
# 5.0
# <class 'float'>
# 5
# <class 'int'>
# 5
# <class 'str'>
# 5.9
# <class 'float'>
# 5
# <class 'int'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1153/760420526.py in <cell line: 0>()
#      69
#      70
# ---> 71 print(int(b)) # b is a string here , so it cannot be converted to integer here
#      72 print(type(b))
#      73
#
# ValueError: invalid literal for int() with base 10: 't'

# %%
# 2.6) Adding String and Integer Without Conversion

a = 5
b = 't'

n = a+b

print(n)
print(type(n))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1153/3340736876.py in <cell line: 0>()
#       4 b = 't'
#       5
# ----> 6 n = a+b
#       7
#       8 print(n)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# 2.6) Adding String and Integer Without Conversion  :We should first convert the string into an integer and then add:

a = 5
b = '7'

# explicit conversion of string to int
n = a + int(b)
print(n)
print(type(n))
# Out:
# 12
# <class 'int'>

# %% [markdown]
# #***Python String :***
#
# - Strings are sequence of characters written inside quotes. It can include letters, numbers, symbols and spaces. Python does not have a separate character type.
#
# - A single character is treated as a string of length one.
# Strings are commonly used for text handling and manipulation.
#
# ***Creating a String :***
#   - Strings can be created using either single ('...') or double ("...") quotes. Both behave the same.
#
# ***Multi-line Strings :***
#   - Use triple quotes ('''...''' ) or ( """...""") for strings that span multiple lines. Newlines are preserved.
#
# ***Accessing Characters in String :***
#   - Strings are indexed sequences. Positive indices start at 0 from the left, negative indices start at -1 from the right as represented in below image:
#   ![image.png](data:image/png;base64,...)
#
# ***String Slicing :***
#   - Slicing is a way to extract a portion of a string by specifying the start and end indexes. The syntax for slicing is string  [start:end], where start starting index and end is stopping index (excluded).
#
# ***Looping Through Strings :***
#   - Strings are iterable, which means we can access each character one by one using a loop.
#
# ***String Immutability :***
#   - Strings are immutable, meaning their values cannot be changed after creation. Any modification to a string creates a new string instead of altering the original one.
#
# ***Deleting a String :***
#   - Individual characters of a string cannot be deleted because strings are immutable. However, an entire string variable can be removed using del keyword.
#
# ***Updating a String :***
#   - Strings cannot be changed directly after creation. So any modification results in a new string being created using slicing or methods like replace( ).
#
# #***Common String Methods :***
#   - Python provides various built-in methods to manipulate strings. Below are some of the most useful methods:
#
#     - 1) len( ): returns the total number of characters in a string (including spaces and punctuation).
#     - 2) upper( ) and lower( ): upper( ) method converts all characters to uppercase whereas, lower( ) method converts all characters to lowercase.
#     - 3) strip() and replace(): strip() removes leading and trailing whitespace from the string and replace() replaces all occurrences of a specified substring with another.
#
# #***Concatenating and Repeating Strings :***
#   - 1) Concatenation: Strings can be combined by using + operator.
#   - 2) Repetition: A string can be repeated multiple times using *.
#
# #***Formatting Strings :***
#   - 1) Using f-strings: f-strings allows to directly insert variables and expressions inside a string using { } brackets.
#   - 2) Using format( ): format( ) method allows inserting values into placeholders { } inside a string.
#
# #***String Membership Testing :***
#    - 'in' keyword is used to check whether a substring exists inside a string. It returns True if the substring is found, otherwise it returns False.

# %%
# Creating a string :

a = 'GFG'
b = "GeeksForGeeks"
print(a)
print(b)

# Multi-line string :
s = """I am Learning
Python String on GeeksforGeeks"""
print(s)

s = '''I'm a
Geek'''
print(s)
# Out:
# GFG
# GeeksForGeeks
# I am Learning
# Python String on GeeksforGeeks
# I'm a
# Geek

# %%
# Accessing Characters in String :

# Example 1: Access specific characters through positive indexing.


s = "ABCDEF"

print(s[0])
print(s[4])
print(s[2])

# Note: Accessing an index out of range will cause an IndexError.Only integers are allowed as indices and using a float or other types will result in a TypeError.

# Example 2: Read characters from the end using negative indices.

s = "ABCDEF"
print(s[-3])
print(s[-5])
print(s[-6])
# Out:
# A
# E
# C
# D
# B
# A

# %%
# String Slicing : Slicing is a way to extract a portion of a string by specifying the start and end indexes. The syntax for slicing is string[start:end], where start starting index and end is stopping index (excluded).

s = "ABCDEF"
print(s[1:4])
print(s[:3])
print(s[3:])
print(s[::-1])
# Out:
# BCD
# ABC
# DEF
# FEDCBA

# %%
# Looping Through Strings : Strings are iterable, which means we can access each character one by one using a loop.

s = "ABCDEF"
for char in s:
    print(char)  # Explanation: for loop goes through the string in order and each iteration prints the next character.
# Out:
# A
# B
# C
# D
# E
# F

# %%
# String Immutability :

s = "aBCDEF"
s = "A" + s[1:]
print(s)  #Explanation: original string "aBCDEF" is not modified. A new string is created by combining "A" with s[1:] (rest of the string).


# Deleting a String :

s = "ABC"
del s  #Note: After deleting a string, if we try to access it, Python raises a NameError because the variable no longer exists in memory.


# Updating a String :
s = "ABCD EF"
s1 = "H" + s[1:]
s2 = s.replace("ABC", "abc")

print(s1)  # A is replaced by H , so output will be "HBCD EF"
print(s2)  # ABC is replaced by abc , so output will be " abcD EF"
# Out:
# ABCDEF
# HBCD EF
# abcD EF

# %%
# Common String Methods :

  # 1. len():

s = "Geeks for Geeks"
print(len(s))  # len( ) includes all the characters and whitespaces.

  # 2. upper() and lower():

s = "Hello World"
print(s.upper()) # .upper() gives all the characters in capitals.
print(s.lower()) # .lower() gives all the characters in small letters.

  #3. strip() and replace():

s = "   ABC   "
print(s.strip())    # strip( ) removes leading and trailing whitespace from the string

s = "Python is fun and people  feel fun about it"
print(s.replace("fun", "awesome")) # replace() replaces all occurrences of a specified substring with another string given.



# Concatenating and Repeating Strings :

  # 1. Concatenation: using + operator.

s1 = "Hello"
s2 = "World"
print(s1 + " " + s2)

  # 2. Repetition: string can be repeated multiple times using *.

s = "Hello "
print(s * 3)

# Formatting Strings :

  # 1. Using f-strings : allows to directly insert variables and expressions inside a string using {} brackets.

name = "Jake"
age = 22
print(f"Name: {name}, Age: {age}")

  # 2. Using format() : allows inserting values into placeholders {} inside a string.

s = "My name is {} and I am {} years old.".format( "Emily", 22)
print(s)

# String Membership Testing :

s = "GeeksforGeeks"
print("Geeks" in s)  # If the substring is there in the original string , then output will be true , here it is true.
print("GfG" in s)    # If the substring is not there in the original string , then output will be false , here it is false.
# Out:
# 15
# HELLO WORLD
# hello world
# ABC
# Python is awesome and people  feel awesome about it
# Hello World
# Hello Hello Hello
# Name: Jake, Age: 22
# My name is Emily and I am 22 years old.
# True
# False

# %% [markdown]
# #***Python Variables :***
#
# - Variables are used to store data that can be referenced and manipulated during program execution. A variable is essentially a name that is assigned to a value.
#
#   - Unlike Java and many other languages, Python variables do not require explicit declaration of type.
#   - Type of the variable is inferred based on the value assigned.
#
# ***Rules for Naming Variables :***
#
# To use variables correctly, the following naming rules should be followed:
#
#  - Names can contain letters, digits and underscores (_).
#  - The first character cannot be a digit.
#  - Names are case-sensitive, so ***myVar*** and ***myvar*** are treated differently.
#  - Keywords such as ***if, else and for*** cannot be used as variable names.
#
# ***Assigning Values to Variables :***
#
# 1. *Basic Assignment* : Variables are assigned values using the = operator.
# 2. *Dynamic Typing :* Python is dynamically typed, so the same variable can store different data types during execution.
# 3. *Assigning Same Value :* same value can be assigned to multiple variables in a single line.
# 4. *Assigning Different Values :* Multiple variables can also be assigned different values in a single line.
#
# ***Concept of Object Reference :***
#
#   1.Let us assign a variable x to value 5.
#
#   - x = 5
#   - When x = 5 is executed, Python creates an object to represent the value 5 and makes x reference this object.
#   ![image.png](data:image/png;base64,...)
# 2. Now, let's assign another variable y to the variable x.
#
#   - y = x
#   - This statement creates y and references the same object as x, not x itself. This is called a Shared Reference, where multiple variables reference the same object.
#   ![image.png](data:image/png;base64,...)
#
#  3.Now, if we write
#
#    - x = 'Geeks'
#    - Python creates a new object for the value "Geeks" and makes x reference this new object.
#    ![image.png](data:image/png;base64,...)
#
# 4.The variable y remains unchanged, still referencing the original object 5. Now, If we assign a new value to y:
#
#   - y = "Computer"
#   ![image.png](data:image/png;base64,...)
#
#
#  - Python variables store references to objects, not the actual values themselves. When a variable is reassigned, it starts referencing a new object while the old unreferenced object becomes eligible for garbage collection.
#
# ***Deleting a Variable :***
#  - *del* keyword is used to delete a variable from memory. After deletion, the variable can no longer be accessed.

# %%
# ASSIGNING VARIABLES SOME VALUE :

x = 5  # x stores value of 5 and whenever "x" is called , it points reference to 5
name = "Alex"   # here "name" stores value as Alex and whenever "name" is called , it points to "Alex"

print(x)
print(name)
# Out:
# 5
# Alex

# %%
# Rules for Naming Variables :

# 1.Below listed variable names are valid:
age = 21
_colour = "lilac"
total_score = 90

# 2.Below listed variables names are invalid:

1name = "Error"  # Starts with a digit
class = 10       # class is a reserved keyword
user-name = "Doe"  # Contains a hyphen

# %%
# Assigning Values to Variables :

# 1. Basic Assignment:

x = 5
y = 3.14
z = "Hi"

# 2. Dynamic Typing: Python is dynamically typed, so the same variable can store different data types during execution.

x = 10
x = "Now a string"   # here as soon as x variable's value is changed , it stores new value and points new value when executed

# 3. Assigning Same Value in the same line:

a = b = c = 100  # here all the variables a,b,c stores value of 100.
print(a, b, c)

# 4. Assigning Different Values: Multiple variables can also be assigned different values in a single line.

x, y, z = 1, 2.5, "Python"
print(x, y, z)

# Understanding Variable Reassignment: In this example, we check whether modifying one variable affects another when both initially reference the same object.

x = 1 # x stores 1
y = x # y stores same value as x
y = y + 1 # here new y gives the output as 2 , y pointing as 1 , plus 1 , so new y will be 2. So from here y value remains to be 2 until changed.

print(x)
print(y)

# Deleting a Variable :

x = 10
del x
print(x)  # we get an error stating that the " NameError: name 'x' is not defined "
# Out:
# 100 100 100
# 1 2.5 Python
# 1
# 2
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_961/2676687695.py in <cell line: 0>()
#      35 x = 10
#      36 del x
# ---> 37 print(x)  # we get an error stating that the " NameError: name 'x' is not defined "
#
# NameError: name 'x' is not defined

# %% [markdown]
# #***Practical Examples:***

# %%
# 1. Swapping Two Variables: Using multiple assignments, we can swap the values of two variables without needing a temporary variable.

a, b = 5, 10
a, b = b, a  # now the values of a and b will be swapped , so then new value of a will be 10 , b will be 5
print(f"swapped value of a will be :{a}\nswapped value of b will be: {b}")
# Out:
# swapped value of a will be :10
# swapped value of b will be: 5

# %%
# 2. Counting Characters in a String: Assign the results of multiple operations on a string to variables in one line.


word = "Python Programming is awesome"
length = len(word)
print("Length of the word:", length)
# Out:
# Length of the word: 29

# %% [markdown]
# #***Conditional Statements and Flow Control :***
#
#
# # ***Python If Else Statements - Conditional Statements :***
#
#  - If-Else statements are conditional statements used to perform decision-making in a program. They allow different blocks of code to execute based on whether a condition is True or False.
#
# # ***1) if Statement :***
# - The if statement is used to execute a block of code only when a given condition is True. If the condition is False, the code inside the if block is skipped.
#
# ![image.png](data:image/png;base64,...)
#
# # ***2)if-Else Statement :***
# - The if-else statement is used to execute one block of code when a condition is True and another block when the condition is False. It helps programs make decisions based on different conditions.
#
# ![image.png](data:image/png;base64,...)
#
# ***If-Else in One line :***
# - If we need to execute a single statement inside the if or else block then one-line shorthand can be used.
#
# ***Logical Operators with If-Else :***
# - We can combine multiple conditions using logical operators such as and, or, not.
#
# #***3) Nested If-Else Statement :***
# - A nested if-else statement is an if-else structure placed inside another if or else block. It is used to check multiple conditions step by step and execute code based on those conditions.
#
# ![image.png](data:image/png;base64,...)
#
# #***4)if-elif-else Statement :***
# - The if-elif-else statement is used to check multiple conditions one by one. When a condition becomes True, its corresponding block of code is executed. If none of the conditions are True, the else block runs.
#
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %%
# if Statement :

i = 10

if i > 15:
    print(" i is greater than 15 ")
print("i is lesser than 15")
# Out:
# i is lesser than 15

# %%
# if-Else Statement :

i = 20

if i > 0:
    print("i is positive")
else:
    print("i is 0 or Negative")
# Out:
# i is positive

# %%
# If-Else in One line :

a = -2
res = "Positive" if a >= 0 else "Negative"
print(res)

a = 25
answer = "a is positive " if a>= 0 else "a is negative "
print(answer)
# Out:
# Negative
# a is positive

# %%
# Logical Operators with If-Else :

age = 25
exp = 10

if age > 23 and exp > 8:
    print("Eligible.")
else:
    print("Not eligible.")
# Out:
# Eligible.

# %%
# Nested If-Else Statement :

i = 10
if i == 10:

    if i < 15:
        print("i is smaller than 15")

    if i < 12:
        print("i is smaller than 12 too")
    else:
        print("i is greater than 15")

else:
  print("i is not equal to 10")
# Out:
# i is smaller than 15
# i is smaller than 12 too

# %%
# if-elif-else Statement :

i = 25

if i == 10:
    print("i is 10")

elif i == 15:
    print("i is 15")

elif i == 20:
    print("i is 20")

else:
    print("i is not present")
# Out:
# i is not present

# %% [markdown]
# #***Python For Loops :***
#
# - Python for loops are used to iterate over sequences such as lists, tuples, strings and ranges.
#   - Allows the same operation to be applied to every item in a sequence.
#   - Avoids the need to manage loop indices manually.
#
# *Flowchart of For Loop :*
#
#   - *Syntax*
#
#     for variable in sequence:
#
#       code block
#
# ![image.png](data:image/png;base64,...)
#
# *Loop Through String :*
#
#  - Here, for loop is used to iterate through each character of the string and prints them one by one.
#
#
# *range() Method :*
#  - range() function is used with for loops to generate a sequence of numbers. It can take one, two or three arguments:
#    - range(stop) generates numbers from 0 to stop-1.
#    - range(start, stop) generates numbers from start to stop-1.
#    - range(start, stop, step) generates numbers from start to stop-1, incrementing by step.
#
# ***Control Statements :***
#
#   - These statements are used to change the normal flow of loop execution in Python. They help control loop behavior by skipping iterations, stopping loops or acting as placeholders inside loops and conditional blocks.
#
#   ***1. Continue Statement :***
#   -  continue skips the current iteration and moves control to the next iteration of the loop.
#
#   ***2. Break Statement :***
#   -  break immediately when a specified condition is met.
#
#   ***3. Pass Statement :***
#   - pass is used as a placeholder when no code needs to be executed.
#
#   ***4. Else Statement :***
#   -  else block with a loop executes only when the loop completes normally without a break statement.
#
# ***Using Enumerate :***
#   - enumerate() is used with a *for loop* to access both the index and the value of each item during iteration.
#
# ***Nested For Loops :***
#   - These loops are used when one loop is placed inside another loop. The inner loop runs completely for every iteration of the outer loop.

# %%
# for loops :

a = ["Geeks", "for", "Geeks"]
for i in a:
    print(i)
# Out:
# Geeks
# for
# Geeks

# %%
# Loop Through String :

# Here, for loop is used to iterate through each character of the string and prints them one by one.

s = "Geeks for Geeks"
for i in s:
    print(i)
# Out:
# G
# e
# e
# k
# s
#
# f
# o
# r
#
# G
# e
# e
# k
# s

# %%
# range() Method :

for i in range(0, 10, 2):
    print(i)
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
# 1. Continue Statement: continue skips the current iteration and moves control to the next iteration of the loop.

for i in 'geeksforgeeks':
    if i == 'e' or i == 's':
        continue
    print(i)

# Explanation:

  # for i in 'geeksforgeeks': iterates through each character.
  # if i == 'e' or i == 's': checks for e or s.
# Out:
# g
# k
# f
# o
# r
# g
# k

# %%
# 2. Break Statement: break immediately when a specified condition is met.

for i in 'geeksforgeeks':
    if i == 'e' or i == 's':
        break
print(i)

# Explanation:

  # for i in 'geeksforgeeks': iterates through characters of the string.
  # if i == 'e' or i == 's': checks for e or s.
# Out:
# e

# %%
# 3. Pass Statement: pass is used as a placeholder when no code needs to be executed.


for i in 'geeksforgeeks':
    pass

# Explanation:

  # for i in 'geeksforgeeks': iterates through the string.
  # pass acts as a placeholder and performs no operation.

# %%
# 4. Else Statement: else block with a loop executes only when the loop completes normally without a break statement.


for i in range(1, 4):
    print(i)
else:
    print("No Break\n")

# Explanation:

  # for i in range(1, 4): iterates from 1 to 3.
  # else: executes after loop completion.
  # "No Break" is printed because loop ends normally without break.
# Out:
# 1
# 2
# 3
# No Break

# %%
# Using Enumerate ()

# enumerate() is used with a for loop to access both the index and the value of each item during iteration.

b = ["eat", "sleep", "repeat"]
for i, j in enumerate(b):
    print (i, j)


# Explanation:

  # enumerate(b) returns both index and value from list b.
  # i stores index values and j stores list items.
# Out:
# 0 eat
# 1 sleep
# 2 repeat

# %%
# Nested For Loops

 # These loops are used when one loop is placed inside another loop. The inner loop runs completely for every iteration of the outer loop.

for i in range(1, 4):
    for j in range(1, 4):
        print(i, j)

# Explanation:

 # Outer loop iterates values from 1 to 3.
 # Inner loop also iterates values from 1 to 3.
 # print(i, j) prints every combination of i and j.
# Out:
# 1 1
# 1 2
# 1 3
# 2 1
# 2 2
# 2 3
# 3 1
# 3 2
# 3 3

# %% [markdown]
# #***Python While Loop :***
#
# - While Loop is used to execute a block of statements repeatedly until a given condition is satisfied.
# - When the condition becomes false, the line immediately after the loop in the program is executed.
#
# # Syntax
#
# while expression:
#
#   statement(s)
#
# *Parameters :*
#
#  - condition a boolean expression. If it evaluates to True, code inside the loop will execute.
#  - statement(s) that will be executed during each iteration of the loop.
#
# #*Flowchart of While Loop :*
#
# ![image.png](data:image/png;base64,...)
#
#
# #*Infinite while Loop :*
#
#  - An infinite loop is a loop that keeps running continuously because its condition always remains True. Such loops do not stop on their own and continue executing until the program is manually terminated.
#
# #*Using with continue statement :*
#
#  - Continue statement is used to skip the current iteration of the loop and move directly to the next iteration.
#
# #*Using with break statement :*
#
#  - Break statement is used to immediately terminate the loop when a specific condition becomes True.
#
# #*Using with pass statement :*
#
#  - pass statement is a null statement. It does nothing when executed and is mainly used as a placeholder for future code.
#
#
# #Using with else :*
#
#  - else block in a while loop executes only when the loop finishes normally without encountering a break statement.
#   - In first example, loop completes all iterations, so the else block executes.
#   - In second example, loop stops because of break, so the else block is skipped.

# %%
# Here, the condition for while will be True as long as the counter variable (count) is less than 3.


count = 0
while count < 3:
    count = count + 1
    print("Hello Geek")
# Out:
# Hello Geek
# Hello Geek
# Hello Geek

# %%
# Infinite while Loop :

age = 28
while age > 19:
    print('Infinite Loop')

# Explanation: Here, the condition age > 19 is always True because the value of age never changes inside the loop. Therefore, the loop runs infinitely.

# %%
# Using with continue statement :

i = 0
a = "geeksforgeeks"

print(len(a))
while i < len(a):
    if a[i] == 'e' or a[i] == 's':
        i += 1
        continue
    print(a[i])
    i += 1

# Explanation: Here, whenever the character is 'e' or 's', the loop skips printing it and continues with the next character.
# Out:
# 13
# g
# k
# f
# o
# r
# g
# k

# %%
# Using with break statement :

i = 0
a = 'geeksforgeeks'

while i < len(a):
    if a[i] == 'e' or a[i] == 's':
        i += 1
        break
    print(a[i])
    i += 1

# Explanation: Here, the loop stops as soon as it encounters the character 'e' or 's'.
# Out:
# g

# %%
# Using with pass statement :

a = 'geeksforgeeks'
i = 0
while i < len(a):
    i += 1
    pass

print('Value of i :', i)

#Explanation: Here, the loop runs through all characters of the string, but the pass statement performs no action inside the loop body.
# Out:
# Value of i : 13

# %%
# Using with else:
i = 0
while i < 4:
    i += 1
    print(i)
else:
    print("No Break\n")

i = 0
while i < 4:
    i += 1
    print(i)
    break
else:
    print("No Break")
# Out:
# 1
# 2
# 3
# 4
# No Break
#
# 1

# %% [markdown]
# #***Why Data Structures and Algorithms Are Important to Learn? :***
#
#  - Data Structures and Algorithms (DSA) form the foundation of efficient programming. Understanding these concepts is essential for problem-solving, software design and excelling in competitive programming and job interviews.
#    - In this article, we explore why DSA is important and how it impacts your programming skills and career.
#
# #***Data Structures and Algorithms :***
# #*1. Data Structures :*
# -  Ways of organizing and storing data to access and modify it efficiently. Examples includes: arrays, linked lists, trees, stacks, queues, hash tables and graphs.
# #*2. Algorithms :*
# -  Step-by-step procedures to solve problems. They operate on data structures to perform tasks like searching, sorting and traversing.
# Understanding DSA allows you to solve computational problems efficiently and choose the right tools for specific scenarios.
#
#
# #*Example: Finding Your Roll Number Quickly*
# Imagine a 20,000-page PDF of roll numbers and you want to find roll number 1500:
#
# - Check the middle number (e.g., 1000).
# - Since 1500 > 1000, ignore numbers below 1000.
# - Check the middle of the remaining numbers.
# - Repeat until you find 1500.
#
# This is the binary search algorithm, a fundamental DSA concept that locates data quickly in sorted lists.
#
# #*Importance of Data Structures and Algorithms :*
# *1. Essential for Efficient Problem-Solving :*
# - Data structures organize data, algorithms process it.
# - Right choices make programs faster and memory-efficient.
# - Some problems are unsolvable without proper DSA tools.
#
# *2. Crucial for Job Interviews at Top Tech Companies :*
# - Companies like Google, Amazon, Microsoft, Meta, Apple focus heavily on DSA in interviews.
# - Efficient algorithms reduce computational cost and save company resources.
#
# *3. Improves Coding Skills :*
# - Helps write cleaner, efficient and maintainable code.
# - Understanding code fundamentals makes debugging easier.
#
# *4. Solving Real-World Problems :*
# - DSA helps think logically and solve everyday challenges methodically.
# - From route planning to task organization, the skills are widely applicable.
#
# *5. Competitive Edge in Programming Contests: *
# - Many contests emphasize algorithmic problem-solving under time limits.
# - Strong DSA skills give an advantage in competitions.
#
# *6. Adaptability to New Technologies :*
# - Principles of DSA apply across programming languages.
# - Makes it easier to learn new languages and tools in a fast-changing tech world.
#
# *7. Enhances Decision-Making Skills :*
# - Enables informed choices of data structures and algorithms for a problem.
# - Leads to efficient solutions that save time and resources.
#
# #*Applications of DSA :*
#
# - DSA is used in almost every area of software development:
#   - Operating Systems: Efficient hardware and memory management
#   - Database Systems: Storing, retrieving and managing data
#   - Web Applications: Handling requests and processing data
#   - Social Networks: Modeling connections between users
#   - Navigation Systems: Finding shortest paths (GPS apps)

# %% [markdown]
# #***Python Lists :***
#
# - List is a built-in data structure used to store an ordered collection of items.
# - They are dynamic, resizable and capable of storing multiple data types.
#
#   - Mutable: list elements can be changed, updated, added, or removed after the list is created.
#   - Ordered: elements maintain the order in which they are inserted.
#   - Index-based: elements are accessed using their position, starting from index 0.
#
# ![image.png](data:image/png;base64,...)
#
# #***Creating a List :***
#
# - Lists can be created in several ways, such as using square brackets [], the list() constructor or by repeating elements.
#
# *1.Using Square Brackets :*
#   - Square brackets [] are used to create a list directly.
#
# *2. Using list() Constructor :*
#   - A list can also be created by passing an iterable (such as tuple, string or another list) to the list() constructor.
#
# *3. Creating List with Repeated Elements :*
#   - A list with repeated elements can be created using the multiplication (*) operator.
#
# #*Internal Representation of Lists :*
#  - Python list stores references to objects, not the actual values directly.
#    - The list keeps memory addresses of objects like integers, strings or booleans.
#    - Actual objects exist separately in memory.
#    - Modifying a mutable object inside a list changes the original object.
#    - Reassigning an immutable object creates a new object instead of changing the old one.
#
#
# #*Accessing Elements :*
#   - Elements in a list are accessed using indexing. Python uses zero-based indexing, meaning a[0] represents the first element. Negative indexing is also supported, where -1 accesses the last element.
#
# #*Adding Elements :*
#   - Elements can be added to a list using the following methods:
#
#      *1. append( ):* Adds an element at the end of the list.
#
#      *2. insert( ):* Adds an element at a specific position.
#
#      *3. extend( ):* Adds multiple elements to the end of the list.
#
# #*Updating Elements :*
#   - Since lists are mutable, elements can be updated by assigning new values using their index.
#
# #*Removing Elements :*
#
# - Elements can be removed from a list using the following methods:
#
#   *1. remove( ) :* Removes the first occurrence of an element.
#
#   *2. pop( ) :* Removes the element at a specific index or the last element if no index is specified.
#
#   *3. del statement :* Deletes an element at a specified index.
#
#   *4. clear( ) :* removes all items.
#
# #*Iterating Over Lists :*
#  - Lists can be iterated using loops, allowing operations to be performed on each element.
#
# #*Nested Lists :*
#  - A nested list is a list that contains another list as its element. It is commonly used to represent matrices or tabular data. Nested elements can be accessed by chaining multiple indexes.

# %%
 # Creating a List :

 # 1. Using Square Brackets: Square brackets [] are used to create a list directly.


a = [1,2,3]
print([a]) # gives a 2d matrix
print(a)

a = [1,2,3.5, "Kiran" ,2+3j , True ] # list is a homogeneous data structure
print(a)

# 2. Using list() Constructor: A list can also be created by passing an iterable (such as tuple, string or another list) to the list() constructor.

a = list((1, 2, 3, 'apple', 4.5))
print(a)

b = list("GFG")
print(b)

#3. Creating List with Repeated Elements: A list with repeated elements can be created using the multiplication (*) operator.

a = [2] * 5
b = [0] * 7

print(a)
print(b)


# Internal Representation of Lists :

a = [1, 2, 2, "Python"]
print(a[0])   # index-based
print(a)

#Accessing Elements : Elements in a list are accessed using indexing. Python uses zero-based indexing, meaning a[0] represents the first element. Negative indexing is also supported, where -1 accesses the last element.

a = [10, 20, 30]
print(a[0])
print(a[-1])
# Out:
# [[1, 2, 3]]
# [1, 2, 3]
# [1, 2, 3.5, 'Kiran', (2+3j), True]
# [1, 2, 3, 'apple', 4.5]
# ['G', 'F', 'G']
# [2, 2, 2, 2, 2]
# [0, 0, 0, 0, 0, 0, 0]
# 1
# [1, 2, 2, 'Python']
# 10
# 30

# %%
#Adding Elements

  #1. append( ) : adds an element to the end of the list

a = [1,2,3,4,5]
a.append(6) # 6 gets added at the end of the list
print(a)

a = [2,5+8j,True,"Kiran","Data Science"]
a.append("Data Analytics")
print(a)

#2. insert(): Adds an element at a specific position.

a = [1, 3]
a.insert(1, 2) #(at index , element needed to be inserted)>> here (1,2) means at 1st index , it inserts element 2
print(a)

a = [2,3,4,5,6]
a.insert(0,1) #(at index , element needed to be inserted)>> here (0,1) means at 0th index , it inserts element 1
print(a)

#3. extend(): Adds multiple elements to the end of the list.

a = [1, 2]
a.extend([3, 4]) # it extends the list with another list but use ([ ]) to extend the actual list
print(a)

a = [21,22,23]
a.extend(["Kiran" ,"Keerthi" ,"Thanu"])
print(a)
# Out:
# [1, 2, 3, 4, 5, 6]
# [2, (5+8j), True, 'Kiran', 'Data Science', 'Data Analytics']
# [1, 2, 3]
# [1, 2, 3, 4, 5, 6]
# [1, 2, 3, 4]
# [21, 22, 23, 'Kiran', 'Keerthi', 'Thanu']

# %%
# Updating Elements :

# Since lists are mutable, elements can be updated by assigning new values using their index.

a = [10, 20, 30, 40, 50]
a[1] = 25    # at 1st index we have 20 here , so now we are assigning the same index with another value 25 , so now 1st index refers to 25
print(a)

a = ["Kiran" , "Data Science" ,"Data analytics"]
a[2] = "Data Analytics"
print(a)
# Out:
# [10, 25, 30, 40, 50]
# ['Kiran', 'Data Science', 'Data Analytics']

# %%
# Removing Elements : Elements can be removed from a list using the following methods:

# 1. remove(): Removes the first occurrence of an element.

a = [1, 2, 3]
a.remove(2)  # here it removes the element , but doesnt follow the index condition , so we need to remove 2 , so 2 gets removed.
print(a)

a = ["Kiran" , "Data Science" ,"Data analytics"]
a.remove("Kiran") # here it removes the element , but doesnt follow the index condition , so we need to remove Kiran , so Kiran gets removed.
print(a)

# 2. pop(): Removes the element at a specific index or the last element if no index is specified.

a = [1, 2, 3]
a.pop()  #since the index or the element is not specified , by default it removes the last element.
print(a)

a = ["Kiran" , "Data Science" ,"Data analytics"]
a.pop(0) # since the index is specified as 0 , 0th index element will get removed.
print(a)

a = ["Kiran" , "Data Science" ,"Data analytics"]
a.pop() #since the index or the element is not specified , by default it removes the last element.
print(a)

# 3. del statement: Deletes an element at a specified index.

a = [1, 2, 3]
del a[1] # deletes the element at the specified index , here 1st index gets removed
print(a)

a = [1, 2, 3]
del a[2] # deletes the element at the specified index , here 2nd index gets removed
print(a)



#4. clear(): removes all items.

a = [1, 2, 3]
a.clear() # all items in the list gets cleared and gives out an empty list.
print(a)

a = ["Kiran" , "Data Science" ,"Data analytics"]
a.clear()
print(a)
# Out:
# [1, 3]
# ['Data Science', 'Data analytics']
# [1, 2]
# ['Data Science', 'Data analytics']
# ['Kiran', 'Data Science']
# [1, 3]
# [1, 2]
# []
# []

# %%
# Iterating Over Lists : Lists can be iterated using loops, allowing operations to be performed on each element.


a = ['apple', 'banana', 'cherry']
for item in a: # here for loop iterates each element in the list and gives the same as output
    print(item)


a = ["Kiran" , "Data Science" ,"Data analytics" ,'apple', 'banana', 'cherry']
for i in a : # here for loop iterates each element in the list and gives the same as output
  print(i)
# Out:
# apple
# banana
# cherry
# Kiran
# Data Science
# Data analytics
# apple
# banana
# cherry

# %%
#Nested Lists : A nested list is a list that contains another list as its element. It is commonly used to represent matrices or tabular data. Nested elements can be accessed by chaining multiple indexes.

a = [[1, 2], [3, 4]] # list inside list , here each list has its own index
print(a[0])  # points the 0th index and output comes out to be [1,2]
print(a[1][0]) # here 1 indicates that it shud look  the 1st index element , which is a list here , so from that list it gives the 0th index element , which is 3 here
# Out:
# [1, 2]
# 3

# %% [markdown]
# #***Multi-dimensional Lists in Python :***
#
#  - In Python, a Multi-dimensional List is a list containing other lists, often used to represent structured data like matrices, tables or 2D arrays. It’s useful for storing and accessing data in rows and columns, commonly applied in data analysis, mathematics and image processing.
#
# #*Creating a Multidimensional List :*
#   - A multidimensional list is created by nesting lists within a single list. It allows data to be organized in rows and columns, similar to a matrix or table.
#
# #*Creating a Multidimensional Zero Matrix :*
#   - A zero matrix is a 2D list with all elements set to zero. It’s commonly used as an initial structure for mathematical operations, data storage or placeholders before inserting actual values.
#
# #*Accessing a Multidimensional List :*
#  *1. Using Row-by-Row Loop :*
#
#   - This approach retrieves each row from the outer list directly. It’s useful when you want to process or print entire rows one at a time without worrying about column indices.
#
# *2. Using Index-Based Nested Loops :*
#
# - This method accesses each element using row and column indices. It provides complete control when working with individual elements.
#
#
# #***Methods on Multidimensional Lists :***
#
# #1. Using append( ) :
#
#  - Adds a new sublist (row) to the end of the outer list. Commonly used when dynamically building matrices or adding data rows.
#
# #2. Using extend( ) :
#
# - Extends a chosen sublist by adding multiple elements from another iterable. Useful for appending more data to an existing row.
#
# #3. Using reverse( ) :
#
# - Reverses the order of elements within a list. It can be applied either to a specific sublist or to the entire outer list.
#
# #4. Using Indexing to Read/Write Element :
#
# - You can directly access or modify elements in a specific position using double indexing syntax a[i][j].
#
# #5. Using List Comprehension for Processing Rows :
#
# - List comprehensions provide a compact way to modify or filter elements in rows or columns, ideal for data transformations like scaling or filtering.
